# %% [markdown]
# # Limpieza de bienes raíces
#
# Este es un conjunto de datos (dataset) reales que fue descargado usando técnicas de web scraping. La data contiene registros de **Fotocasa**, el cual es uno de los sitios más populares de bienes raíces en España. Por favor no hagas esto (web scraping) a no ser que sea para propósitos académicos.
#
# El dataset fue descargado hace algunos años por Henry Navarro y en ningún caso se obtuvo beneficio económico de ello.
#
# Contiene miles de datos de casas reales publicadas en la web www.fotocasa.com. Tu objetivo es extraer tanta información como sea posible con el conocimiento que tienes hasta ahora de ciencia de datos, por ejemplo ¿cuál es la casa más cara en todo el dataset?
#
# Empecemos precisamente con esa pregunta... ¡Buena suerte!

# %% [markdown]
# #### Ejercicio 00. Lee el dataset assets/real_estate.csv e intenta visualizar la tabla (★☆☆)

# %%
import pandas as pd

# Este archivo CSV contiene puntos y comas en lugar de comas como separadores
df = pd.read_csv('assets/real_estate.csv', sep=';')
df
# Out:
#        Unnamed: 0  id_realEstates  isNew                    realEstate_name  \
# 0               1       153771986  False            ferrari 57 inmobiliaria
# 1               2       153867863  False  tecnocasa fuenlabrada ferrocarril
# 2               3       153430440  False                 look find boadilla
# 3               4       152776331  False  tecnocasa fuenlabrada ferrocarril
# 4               5       153180188  False            ferrari 57 inmobiliaria
# ...           ...             ...    ...                                ...
# 15330       15331       153901377  False                infocasa consulting
# 15331       15332       150394373  False                inmobiliaria pulpon
# 15332       15333       153901397  False             tecnocasa torrelodones
# 15333       15334       152607440  False                inmobiliaria pulpon
# 15334       15335       153901356  False                infocasa consulting
#
# ...

# %% [markdown]
# #### Ejercicio 01. ¿Cuál es la casa más cara en todo el dataset? (★☆☆)
#
# Imprime la dirección y el precio de la casa seleccionada. Por ejemplo:
#
# `La casa con dirección en Calle del Prado, Nº20 es la más cara y su precio es de 5000000 USD`

# %%
la_casa_mas_cara = df.loc[df['price'].idxmax()]

ubicacion = la_casa_mas_cara['address']
precio = la_casa_mas_cara['price']

print("La casa con dirección en", ubicacion, "es la más cara y su precio es de",precio )
# Out:
# La casa con dirección en El Escorial es la más cara y su precio es de 8500000

# %% [markdown]
# #### Ejercicio 02. ¿Cuál es la casa más barata del dataset? (★☆☆)
#
# Imprime la dirección y el precio de la casa seleccionada. Por ejemplo:
#
# `La casa con dirección en Calle Alcalá, Nº58 es la más barata y su precio es de 12000 USD`

# %%
filtro = df[df['price']>0]
la_casa_mas_barata = filtro.loc[filtro['price'].idxmin()]

ubicacion = la_casa_mas_barata['address']
precio = la_casa_mas_barata['price']

print("La casa con dirección en", ubicacion, "es la más cara y su precio es de",precio )
# Out:
# La casa con dirección en Berlin, Coslada es la más cara y su precio es de 600

# %% [markdown]
# #### Ejercicio 03. ¿Cuál es la casa más grande y la más pequeña del dataset? (★☆☆)
#
# Imprime la dirección y el área de las casas seleccionadas. Por ejemplo:
#
# `La casa más grande está ubicada en Calle Gran Vía, Nº38 y su superficie es de 5000 metros`
#
# `La casa más pequeña está ubicada en Calle Mayor, Nº12 y su superficie es de 200 metros`

# %%
grande = df.loc[df['surface'].idxmax()]
pequeña = df.loc[df['surface'].idxmin()]

print("La casa mas grande está ubicada en", grande['address'], "y su superficie es de",grande['surface'], "metros." )
print("La casa mas pequeña está ubicada en", pequeña['address'], "y su superficie es de",pequeña['surface'], "metros." )
# Out:
# La casa mas grande está ubicada en Sevilla la Nueva y su superficie es de 249000.0 metros.
# La casa mas pequeña está ubicada en Calle Amparo,  Madrid Capital y su superficie es de 15.0 metros.

# %% [markdown]
# #### Ejercicio 04. ¿Cuantas poblaciones (columna level5) contiene el dataset? (★☆☆)
#
# Imprime el nombre de las poblaciones separadas por coma. Por ejemplo:
#
# `> print(populations)`
#
# `population1, population2, population3, ...`

# %%
populations = df['level5'].unique()
contador = len(populations)
print("El dataset tiene", contador, "poblaciones")

print("Las poblaciones son:",", ".join(populations))
# Out:
# El dataset tiene 168 poblaciones
# ...

# %% [markdown]
# #### Ejercicio 05. ¿El dataset contiene valores no admitidos (NAs)? (★☆☆)
#
# Imprima un booleano (`True` o `False`) seguido de la fila/columna que contiene el NAs.

# %%
Valores_NAs = df.isnull().any().any()
print("El dataset contiene valores no admitidos (NAs):", Valores_NAs)

cantidad_de_NAs_por_columna = df.columns[df.isnull().any()]

print("Contiene valores no admitidos (NAs) en:", cantidad_de_NAs_por_columna.tolist())
# Out:
# El dataset contiene valores no admitidos (NAs): True
# Contiene valores no admitidos (NAs) en: ['realEstate_name', 'phone_realEstate', 'rooms', 'bathrooms', 'surface', 'description', 'level4', 'level6', 'level7', 'level8', 'zipCode', 'customZone']

# %% [markdown]
# #### Ejercicio 06. Elimina los NAs del dataset, si aplica (★★☆)
#
# Imprima una comparación entre las dimensiones del DataFrame original versus el DataFrame después de las eliminaciones.

# %%
print("Las dimensiones del DataFrame original son:", df.shape)
df_nuevo = df.dropna()
print("Las dimensiones del DataFrame sin NAs son:", df_nuevo.shape)
# Out:
# Las dimensiones del DataFrame original son: (15335, 37)
# Las dimensiones del DataFrame sin NAs son: (0, 37)

# %% [markdown]
# #### Ejercicio 07. ¿Cuál la media de precios en la población (columna level5) de "Arroyomolinos (Madrid)"? (★★☆)
#
# Imprima el valor obtenido.

# %%
Arroyosmolinos = df[df['level5'] == "Arroyomolinos (Madrid)"]

media = Arroyosmolinos['price'].mean()

print("La media es:", media)
# Out:
# La media es: 294541.59854014596

# %% [markdown]
# #### Ejercicio 08. Trazar el histograma de los precios para la población (level5 column) de "Arroyomolinos (Madrid)" y explica qué observas (★★☆)
#
# Imprime el histograma de los precios y escribe en la celda del Markdown un breve análisis del trazado.

# %%
import matplotlib.pyplot as plt

precios_A = Arroyosmolinos['price']

plt.figure(figsize=(10,5))
plt.hist(precios_A, bins=30, edgecolor = "black")
plt.title("Histograma")
plt.show()

print("Se observa la distribucion de los precios de la población Arroyomolinos. Y se observa tambien que la mayotia de datos estan \n"
      "agrupados en el centro del grafico.")
# Out:
# Se observa la distribucion de los precios de la población Arroyomolinos. Y se observa tambien que la mayotia de datos estan
# agrupados en el centro del grafico.

# %% [markdown]
# **TODO: Markdown**. Para escribir aquí, haz doble clic en esta celda, elimina este contenido y coloca lo que quieras escribir. Luego ejecuta la celda.

# %% [markdown]
# #### Ejercicio 09. ¿Son los precios promedios de "Valdemorillo" y "Galapagar" los mismos? (★★☆)
#
# Imprime ambos promedios y escribe una conclusión sobre ellos.

# %%
Valdemorillo = df[df['level5'] == "Valdemorillo"]
precios_V = Valdemorillo['price'].mean()

Galapagar = df[df['level5'] == "Galapagar"]
precios_G = Galapagar['price'].mean()

print("El promedio de los precios de Valdemorillo es:", precios_V)
print("El promedio de los precios de Galapagar es:", precios_G)
print("Los precios promedios son distinos.")
# Out:
# El promedio de los precios de Valdemorillo es: 363860.2931034483
# El promedio de los precios de Galapagar es: 360063.20238095237
# Los precios promedios son distinos.

# %% [markdown]
# #### Ejercicio 10. ¿Son los promedios de precio por metro cuadrado (precio/m2) de "Valdemorillo" y "Galapagar" los mismos? (★★☆)
#
# Imprime ambos promedios de precio por metro cuadrado y escribe una conclusión sobre ellos.
#
# Pista: Crea una nueva columna llamada `pps` (*price per square* o precio por metro cuadrado) y luego analiza los valores.

# %%
df['pps'] = df['price']/df['surface']

Valdemorillo = df[df['level5'] == "Valdemorillo"]
pps_V = Valdemorillo['pps'].mean()

Galapagar = df[df['level5'] == "Galapagar"]
pps_G = Galapagar['pps'].mean()

print("Promedio de precio por metro cuadrado de Valdemorillo es: ", pps_V)
print("Promedio de precio por metro cuadrado de Galapagar es: ", pps_G)
print("Los promedios de pps son distintos")
# Out:
# Promedio de precio por metro cuadrado de Valdemorillo es:  1317.9502109024986
# Promedio de precio por metro cuadrado de Galapagar es:  1606.3240303094024
# Los promedios de pps son distintos

# %% [markdown]
# #### Ejercicio 11. Analiza la relación entre la superficie y el precio de las casas. (★★☆)
#
# Pista: Puedes hacer un `scatter plot` y luego escribir una conclusión al respecto.

# %%
superficie = df['surface']
precio = df['price']

plt.figure(figsize=(10,5))
plt.scatter(superficie, precio, alpha= 0.4)
plt.xlabel("Superficie")
plt.ylabel("Precio (millones)")
plt.title("Relacion entre precio y superficie de las casas")
plt.show()
print("Se puede concluir que los datos estan muy concentrados en superficie = 0, esto se debe a los outliers, si aplicaramos un filtro se podria apreciar mejor la relacion.")
# Out:
# Se puede concluir que los datos estan muy concentrados en superficie = 0, esto se debe a los outliers, si aplicaramos un filtro se podria apreciar mejor la relacion.

# %% [markdown]
# **TODO: Markdown**. Para escribir aquí, haz doble clic en esta celda, elimina este contenido y coloca lo que quieras escribir. Luego ejecuta la celda.

# %% [markdown]
# #### Ejercicio 12. ¿Cuántas agencia de bienes raíces contiene el dataset? (★★☆)
#
# Imprime el valor obtenido.

# %%
agencias = df['realEstate_name'].unique()
numero_agencias = agencias.size

print("El dataset tiene: ", numero_agencias, "agencias.")
# Out:
# El dataset tiene:  1822 agencias.

# %% [markdown]
# #### Ejercicio 13. ¿Cuál es la población (columna level5) que contiene la mayor cantidad de casas?(★★☆)
#
# Imprima la población y el número de casas.

# %%
Poblacion = df['level5'].value_counts()
casa = Poblacion.idxmax()
maximo = Poblacion.max()
print("La poblacion que tiene mayor numero de casas es:", casa, "con", maximo, "casas.")
# Out:
# La poblacion que tiene mayor numero de casas es:  Madrid Capital con 6643 casas.

# %% [markdown]
# #### Ejercicio 14. Ahora vamos a trabajar con el "cinturón sur" de Madrid. Haz un subconjunto del DataFrame original que contenga las siguientes poblaciones (columna level5): "Fuenlabrada", "Leganés", "Getafe", "Alcorcón" (★★☆)
#
# Pista: Filtra el DataFrame original usando la columna `level5` y la función `isin`.

# %%
cinturon_sur = ['Fuenlabrada', 'Leganés', 'Getafe', 'Alcorcón']
df_cs = df[df['level5'].isin(cinturon_sur)]
df_cs
# Out:
#        Unnamed: 0  id_realEstates  isNew  \
# 1               2       153867863  False
# 3               4       152776331  False
# 85             86       153152077  False
# 94             95       153995577  False
# 109           110       153586414  False
# ...           ...             ...    ...
# 15275       15276       153903887  False
# 15291       15292       151697757  False
# 15305       15306       153902389  False
# 15322       15323       153871864  False
# 15325       15326       153901467  False
#
#                                  realEstate_name  phone_realEstate  \
# 1              tecnocasa fuenlabrada ferrocarril       916358736.0
# 3              tecnocasa fuenlabrada ferrocarril       916358736.0
# 85                       sinergical inmobiliaria               NaN
# 94                               viviendas365com       911226014.0
# 109              area uno asesores inmobiliarios       912664081.0
# ...

# %% [markdown]
# #### Ejercicio 15. Traza un gráfico de barras de la mediana de los precios y explica lo que observas (debes usar el subconjunto obtenido del Ejercicio 14) (★★★)
#
# Imprima un gráfico de barras de la mediana de precios y escriba en la celda Markdown un breve análisis sobre el gráfico.

# %%
mediana_precios = df_cs.groupby('level5')['price'].median()
plt.figure(figsize=(10,5))
plt.bar(cinturon_sur,mediana_precios)
plt.title("Mediana de los precios")
plt.show()

# %% [markdown]
# **TODO: Markdown**. Para escribir aquí, haz doble clic en esta celda, elimina este contenido y coloca lo que quieras escribir. Luego ejecuta la celda.

# %% [markdown]
# #### Ejercicio 16. Calcula la media y la varianza de muestra para las siguientes variables: precio, habitaciones, superficie y baños (debes usar el subconjunto obtenido del Ejercicio 14) (★★★)
#
# Imprime ambos valores por cada variable.

# %%
variables = ['price', 'rooms', 'surface', 'bathrooms']
media = df_cs[variables].mean()

varianza = df_cs[variables].var()

print("La media de las variables es: ")
print(media)
print("-----------------------------------")
print("La Varianza de las variables es: ")
print(varianza)
# Out:
# La media de las variables es:
# price        223094.480706
# rooms             3.017738
# surface         111.752224
# bathrooms         1.633222
# dtype: float64
# -----------------------------------
# La Varianza de las variables es:
# price        1.492137e+10
# rooms        7.188859e-01
# surface      4.263052e+03
# bathrooms    5.717969e-01
# dtype: float64

# %% [markdown]
# #### Ejercicio 17. ¿Cuál es la casa más cara de cada población? Debes usar el subset obtenido en la pregunta 14 (★★☆)
#
# Imprime tanto la dirección como el precio de la casa seleccionada de cada población. Puedes imprimir un DataFrame o una sola línea para cada población.

# %%
agrupacion = df_cs.groupby('level5')['price'].idxmax()

casas_mas_caras = df_cs.loc[agrupacion]

casas_mas_caras = casas_mas_caras[['level5', 'address', 'price']]
casas_mas_caras
# Out:
#             level5                                address    price
# 5585      Alcorcón                               Alcorcón   950000
# 11561  Fuenlabrada  Calle de Paulo Freire, 5, Fuenlabrada   490000
# 2881        Getafe                                 Getafe  1050000
# 10412      Leganés           Avenida Reina Sofía, Leganés   650000

# %% [markdown]
# #### Ejercicio 18. Normaliza la variable de precios para cada población y traza los 4 histogramas en el mismo gráfico (debes usar el subconjunto obtenido en la pregunta 14) (★★★)
#
# Para el método de normalización, puedes usar el que consideres adecuado, no hay una única respuesta correcta para esta pregunta. Imprime el gráfico y escribe en la celda de Markdown un breve análisis sobre el gráfico.
#
# Pista: Puedes ayudarte revisando la demostración multihist de Matplotlib.

# %%
df_cs['precio_norm'] = (df_cs['price'] - df_cs['price'].min()) / (df_cs['price'].max() - df_cs['price'].min())

plt.figure(figsize=(10, 6))
for poblacion in df_cs['level5'].unique():
    data = df_cs[df_cs['level5'] == poblacion]['precio_norm']
    plt.hist(data, bins=15, alpha=0.5, label=poblacion)

plt.title('Histogramas de Precios Normalizados por Población')
plt.xlabel('Precio Normalizado')
plt.ylabel('Frecuencia')
plt.legend(title='Poblaciones')
plt.grid(True)

plt.show()
# Out:
# /tmp/ipykernel_721/2142140380.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cs['precio_norm'] = (df_cs['price'] - df_cs['price'].min()) / (df_cs['price'].max() - df_cs['price'].min())

# %% [markdown]
# **TODO: Markdown**. Para escribir aquí, haz doble clic en esta celda, elimina este contenido y coloca lo que quieras escribir. Luego ejecuta la celda.

# %% [markdown]
# #### Ejercicio 19. ¿Qué puedes decir sobre el precio por metro cuadrado (precio/m2) entre los municipios de 'Getafe' y 'Alcorcón'? Debes usar el subconjunto obtenido en la pregunta 14 (★★☆)
#
# Pista: Crea una nueva columna llamada `pps` (price per square en inglés) y luego analiza los valores

# %%
df_cs["pps"] = df_cs["price"] / df_cs["surface"]

print(df_cs.groupby("level5")["pps"].mean())
# Out:
# level5
# Alcorcón       2239.302480
# Fuenlabrada    1796.729220
# Getafe         2066.314949
# Leganés        2047.503268
# Name: pps, dtype: float64
# /tmp/ipykernel_721/3487483308.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cs["pps"] = df_cs["price"] / df_cs["surface"]

# %% [markdown]
# #### Ejercicio 20. Realiza el mismo gráfico para 4 poblaciones diferentes (columna level5) y colócalos en el mismo gráfico. Debes usar el subconjunto obtenido en la pregunta 14 (★★☆)
# Pista: Haz un diagrama de dispersión de cada población usando subgráficos (subplots).

# %%
n_groups = df_cs['level5'].nunique()

fig, axes = plt.subplots(2, 2, figsize=(12, 10))  
axes = axes.flatten()  


for i, (group, data) in enumerate(df_cs.groupby('level5')):
    axes[i].scatter(data['surface'], data['pps'], alpha=0.7)
    axes[i].set_title(f'Grupo: {group}')
    axes[i].set_xlabel('Superficie')
    axes[i].set_ylabel('Pps')


plt.tight_layout()
plt.show()

# %% [markdown]
# #### Ejercicio 21. Realiza un trazado de las coordenadas (columnas latitud y longitud) del cinturón sur de Madrid por color de cada población (debes usar el subconjunto obtenido del Ejercicio 14) (★★★★)
#
# Ejecuta la siguiente celda y luego comienza a codear en la siguiente. Debes implementar un código simple que transforme las columnas de coordenadas en un diccionario de Python (agrega más información si es necesario) y agrégala al mapa.

# %%
from ipyleaflet import Map, basemaps

# Mapa centrado en (60 grados latitud y -2.2 grados longitud)
# Latitud, longitud
map = Map(center = (60, -2.2), zoom = 2, min_zoom = 1, max_zoom = 20, 
    basemap=basemaps.OpenStreetMap.Mapnik)
map
# Out:
# Map(center=[60, -2.2], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_out_t…

# %%
df_cs.loc[:, "latitude"] = df_cs['latitude'].str.replace(',', '.', regex=False)
df_cs.loc[:, "longitude"] = df_cs['longitude'].str.replace(',', '.', regex=False)

# %%
df_cs.loc[:, "latitude"] = df_cs['latitude'].astype(float)
df_cs.loc[:, "longitude"] = df_cs['longitude'].astype(float)

# %%
coordenadas_dict = {}

# Agrupar por la columna 'level5'
for group, data in df_cs.groupby('level5'):
    coordenadas_dict[group] = list(zip(data['latitude'], data['longitude']))

print(coordenadas_dict)
# Out:
# {'Alcorcón': [(40.35059, -3.82693), (40.3313411, -3.8313868), (40.3526, -3.81587), (40.3546326213562, -3.80197422135624), (40.34949, -3.83127), (40.34608, -3.82316), (40.3446968786438, -3.82185872135624), (40.34942, -3.82489), (40.3525293490715, -3.81249633026123), (40.3453965786438, -3.82416582135624), (40.3453965786438, -3.82416582135624), (40.33829, -3.82919), (40.3541132, -3.8009789), (40.3494952, -3.8193922), (40.34368, -3.8455), (40.3314905686438, -3.82336329135624), (40.3470842135624, -3.81097578643763), (40.3442916870117, -3.82681002807617), (40.3489999, -3.82822), (40.34368, -3.8455), (40.3467875, -3.8301848), (40.33163199, -3.82342187), (40.34438, -3.82546), (40.34855, -3.81162), (40.347495990297, -3.8217114947359), (40.345881470732, -3.8105465372741), (0.0, 0.0), (40.34362, -3.82534), (40.34559, -3.82172), (40.3469313664376, -3.83183956356237), (40.3470069724376, -3.82310920943763), (40.34444980446, -3.816518944703), (40.34307648046, -3.8272440218029), (40.3485743497314, -
# ...

# %%
from ipyleaflet import Map, basemaps, Polyline

map = Map(center=(60, -2.2), zoom=2, min_zoom=1, max_zoom=20, basemap=basemaps.OpenStreetMap.Mapnik)

for key, coords in coordenadas_dict.items():
    polyline = Polyline(locations=coords, color="blue", weight=3)
    map.add_layer(polyline)

map
# Out:
# Map(center=[60, -2.2], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_out_t…
